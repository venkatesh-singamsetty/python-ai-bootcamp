# %% [markdown]
# # NUMPY & WORKING WITH IMAGE

# %%
import numpy as np

# %%
ones_arr = np.ones((5,5))
ones_arr

# %%
ones_arr*3

# %%
ones_arr = np.ones((5,5),dtype=int)

# %%
ones_arr*255

# %%
zero_arr = np.zeros((5,5))

# %%
zero_arr

# %%
zero_arr*3

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image #python imageing library

# %%
horse_img = Image.open(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\1. KODI WORK\1. NARESH\10. WORKSHOP\8. Exploring Generative AI through computer vision\horse1.jpg')

# %%
horse_img

# %%
#my_img = Image.open(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\1. KODI WORK\1. NARESH\10. WORKSHOP\8. Exploring Generative AI through computer vision\myimage.jpg')

# %%
#my_img

# %%
#elephant_img = Image.open(r'C:\Users\A3MAX SOFTWARE TECH\Desktop\WORK\1. KODI WORK\1. NARESH\10. WORKSHOP\8. Exploring Generative AI through computer vision\elephant.jpg')

# %%
#elephant_img

# %%
type(horse_img)

# %%
horse_arr = np.asarray(horse_img)
horse_arr

# %%
type(horse_arr)

# %%
horse_arr.shape # image dimension & 3 channel

# %%
plt.imshow(horse_arr) 
#when you execute the code you didnt find the original load img

# %%
horse_red = horse_arr.copy()

# %%
plt.imshow(horse_red)

# %%
horse_red.shape

# %%
# R G B
plt.imshow(horse_red[:,:,0])

# %%
horse_red[:,:,0]

# %%
# https://matplotlib.org/stable/gallery/color/colormap_reference.html
# R G B 

# RED CHANNEL VALUE BETWEEN 0 - 255 || (0- means no red its completely FULL BLACK) 
plt.imshow(horse_red[:,:,0],cmap='gray')

# %%
 # GREEN CHANNEL 
plt.imshow(horse_red[:,:,1],cmap='gray')

# %%
# BLUE CHANNEL 
plt.imshow(horse_red[:,:,2],cmap='gray')

# %%
# red channel
horse_red[:,:,0]

# %%
# green channel
horse_red[:,:,1]

# %%
# Blue channel
horse_red[:,:,2]

# %%
# work with green channel
horse_red[:,:,1] = 0

# %%
horse_red[:,:,1]

# %%
plt.imshow(horse_red)

# %%
# work with blue channel
horse_red[:,:,2]

# %%
horse_red[:,:,2] = 0

# %%
horse_red[:,:,2]

# %%
plt.imshow(horse_red)

# %%
horse_arr

# %%
horse_red

# %%
horse_img

# %%
arr1= np.asarray(horse_img)

# %%
type(arr1)

# %%
arr1.shape

# %%
plt.imshow(arr1)

# %%
horsh_img1 = arr1.copy()

# %%
horsh_img1[:,:,0]

# %%
# RED TO ZERO
horsh_img1[:,:,0] = 0

# %%
plt.imshow(horsh_img1)

# %%
horsh_img1[:,:,1]

# %%
# GREEN TO ZERO
horsh_img1[:,:,1] = 0

# %%
plt.imshow(horsh_img1)
