# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.7/139.7 kB 11.8 MB/s eta 0:00:00
# ...

# %%
from groq import Groq

client = Groq(api_key="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")

completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": "Tell me a short story about a brave knight."
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# In the kingdom of Everwood, where the sun dipped into the horizon and painted the sky with hues of crimson and gold, there lived a brave knight named Sir Edward. He was known throughout the land for his unwavering courage, his unshakeable honor, and his unyielding pursuit of justice.
#
# Sir Edward's armor shone like gold in the sunlight, and his steed, a majestic stallion named Galahad, was as swift and sure-footed as the wind. The knight had sworn to protect the people of Everwood from the dark forces that threatened to engulf them, and he had not faltered in his quest.
#
# One fateful day, as the kingdom's people gathered in the castle courtyard, a messenger arrived from the village of Ashwood, which lay on the outskirts of the kingdom. The villagers were beset by a fearsome dragon that had risen from the depths of the nearby mines, and was now terrorizing the village and its people.
#
# ...

# %%
from groq import Groq

client = Groq(api_key="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")

completion = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
      {
        "role": "user",
        "content": "Generate a cat image"
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# I'm not capable of directly generating images. However, I can try to create a simple ASCII art cat for you:
#
#  /_/\
# ( o.o )
#  > ^ <
#
# I hope you find this adorable ASCII cat endearing! If you're looking for a more complex image, I recommend searching for cat images on a stock photo website or using a image generation tool.

# %%
from groq import Groq

client = Groq(api_key="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")

completion = client.chat.completions.create(
    model="meta-llama/llama-4-scout-17b-16e-instruct",
    messages=[
      {
        "role": "user",
        "content": "Difference between gen ai vs agentic ai"
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# Generative AI (Gen AI) and Agentic AI (Agentic AI) are two concepts that have emerged in the field of artificial intelligence. While both are related to AI, they differ in their focus, capabilities, and applications.
#
# **Generative AI (Gen AI)**
#
# Generative AI refers to a type of AI that focuses on generating new, synthetic data, such as images, videos, music, text, or even code, that resembles existing data. The primary goal of Gen AI is to create novel content that is often indistinguishable from human-created content. Gen AI models are typically trained on large datasets and use techniques like Generative Adversarial Networks (GANs), Variational Autoencoders (VAEs), or transformers to learn patterns and relationships in the data.
#
# Examples of Gen AI applications:
#
# 1. Image generation (e.g., generating faces, objects, or scenes)
# 2. Text generation (e.g., chatbot responses, articles, or stories)
# 3. Music generation (e.g., composing music or generating audio samples)
# ...

# %%
from groq import Groq

client = Groq(api_key="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")

completion = client.chat.completions.create(
    model="meta-llama/llama-prompt-guard-2-86m",
    messages=[
      {
        "role": "user",
        "content": "Difference between gen ai vs agentic ai"
      }
    ],
    temperature=1,
    max_completion_tokens=512,
    top_p=1,
    stream=False,
    stop=None
)

print(completion.choices[0].message.content or "")
# Out:
# 0.0005183074972592294

# %%
from groq import Groq

client = Groq(api_key="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")

completion = client.chat.completions.create(
    model="meta-llama/llama-prompt-guard-2-86m",
    messages=[
      {
        "role": "user",
        "content": "Difference between gen ai vs agentic ai"
      }
    ],
    temperature=1,
    max_completion_tokens=512,
    top_p=1,
    stream=False,
    stop=None
)

print(completion.choices[0].message.content or "")
# Out:
# 0.0005183074972592294
