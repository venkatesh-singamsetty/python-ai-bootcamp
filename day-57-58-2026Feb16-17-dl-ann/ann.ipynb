# %%
pip install tensorflow keras torch opencv-python ultralytics mediapipe langchain langgraph
# Out:
# Requirement already satisfied: tensorflow in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (2.20.0)
# Requirement already satisfied: keras in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (3.13.2)
# Requirement already satisfied: torch in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (2.10.0)
# Requirement already satisfied: opencv-python in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: ultralytics in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (8.4.14)
# Requirement already satisfied: mediapipe in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (0.10.32)
# Requirement already satisfied: langchain in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (1.2.10)
# Requirement already satisfied: langgraph in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (1.0.8)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (82.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (2.4.2)
# Requirement already satisfied: h5py>=3.11.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: pillow in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (12.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.5)
# Requirement already satisfied: rich in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from keras) (14.3.2)
# Requirement already satisfied: namex in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from keras) (0.18.0)
# Requirement already satisfied: filelock in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from torch) (3.24.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ultralytics) (1.17.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ultralytics) (1.38.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: sounddevice~=0.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mediapipe) (0.5.5)
# Requirement already satisfied: opencv-contrib-python in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mediapipe) (4.13.0.92)
# Requirement already satisfied: cffi in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from sounddevice~=0.5->mediapipe) (2.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain) (1.2.13)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph) (0.3.6)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.38.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from polars>=0.20.0->ultralytics) (1.38.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: pycparser in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from cffi->sounddevice~=0.5->mediapipe) (3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values

# %%
dataset
# Out:
#        apst  CustomerId    Surname  CreditScore  Geography  Gender  Age  \
# 0         1    15634602   Hargrave          619      delhi  Female   42
# 1         2    15647311       Hill          608  bangalore  Female   41
# 2         3    15619304       Onio          502      delhi  Female   42
# 3         4    15701354       Boni          699      delhi  Female   39
# 4         5    15737888   Mitchell          850  bangalore  Female   43
# ...     ...         ...        ...          ...        ...     ...  ...
# 9995   9996    15606229   Obijiaku          771      delhi    Male   39
# 9996   9997    15569892  Johnstone          516      delhi    Male   35
# 9997   9998    15584532        Liu          709      delhi  Female   36
# 9998   9999    15682355  Sabbatini          772     mumbai    Male   42
# 9999  10000    15628319     Walker          792      delhi  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
dataset.head()
# Out:
#    apst  CustomerId   Surname  CreditScore  Geography  Gender  Age  Tenure  \
# 0     1    15634602  Hargrave          619      delhi  Female   42       2
# 1     2    15647311      Hill          608  bangalore  Female   41       1
# 2     3    15619304      Onio          502      delhi  Female   42       8
# 3     4    15701354      Boni          699      delhi  Female   39       1
# 4     5    15737888  Mitchell          850  bangalore  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
X
# Out:
# array([[619, 'delhi', 'Female', ..., 1, 1, 101348.88],
#        [608, 'bangalore', 'Female', ..., 0, 1, 112542.58],
#        [502, 'delhi', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'delhi', 'Female', ..., 0, 1, 42085.58],
#        [772, 'mumbai', 'Male', ..., 1, 0, 92888.52],
#        [792, 'delhi', 'Female', ..., 1, 0, 38190.78]],
#       shape=(10000, 10), dtype=object)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0], shape=(10000,))

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
dataset.head(2)
# Out:
#    apst  CustomerId   Surname  CreditScore  Geography  Gender  Age  Tenure  \
# 0     1    15634602  Hargrave          619      delhi  Female   42       2
# 1     2    15647311      Hill          608  bangalore  Female   41       1
#
#     Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0      0.00              1          1               1        101348.88       1
# 1  83807.86              1          0               1        112542.58       0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder() 
X[:, 2] = le.fit_transform(X[:, 2])

# %%
X
# Out:
# array([[619, 'delhi', 0, ..., 1, 1, 101348.88],
#        [608, 'bangalore', 0, ..., 0, 1, 112542.58],
#        [502, 'delhi', 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 'delhi', 0, ..., 0, 1, 42085.58],
#        [772, 'mumbai', 1, ..., 1, 0, 92888.52],
#        [792, 'delhi', 0, ..., 1, 0, 38190.78]],
#       shape=(10000, 10), dtype=object)

# %%
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])],remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[0.0, 1.0, 0.0, ..., 1, 1, 101348.88],
#        [1.0, 0.0, 0.0, ..., 0, 1, 112542.58],
#        [0.0, 1.0, 0.0, ..., 1, 0, 113931.57],
#        ...,
#        [0.0, 1.0, 0.0, ..., 0, 1, 42085.58],
#        [0.0, 0.0, 1.0, ..., 1, 0, 92888.52],
#        [0.0, 1.0, 0.0, ..., 1, 0, 38190.78]],
#       shape=(10000, 12), dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X
# Out:
# array([[-0.57380915,  0.99720391, -0.57873591, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [ 1.74273971, -1.00280393, -0.57873591, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-0.57380915,  0.99720391, -0.57873591, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [-0.57380915,  0.99720391, -0.57873591, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [-0.57380915, -1.00280393,  1.72790383, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [-0.57380915,  0.99720391, -0.57873591, ...,  0.64609167,
#         -1.03067011, -1.07636976]], shape=(10000, 12))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
# Out:
# (8000, 12)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (8000, 12)
# (8000,)
# (2000, 12)
# (2000,)

# %%
ann = tf.keras.Sequential() # establish layer one after another

# %%
ann.add(tf.keras.layers.Dense(units=6)) # input layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu')) # hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid')) # output layer

# %%
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
ann.fit(X_train, y_train, batch_size=32, epochs=10)
