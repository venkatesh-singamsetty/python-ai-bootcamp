# %%
# !nvidia-smi
# Out:
# Mon Nov 17 06:17:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
#!pip install -U \
#    chromadb==0.5.15 \
#    langchain==0.2.11 \
#    langchain-community==0.2.10 \
#    langchain-chroma==0.1.4 \
#    langchain-text-splitters==0.2.2 \
#    langchain-groq==0.1.6 \
#    transformers==4.46.2 \
#    sentence-transformers==3.0.1 \
#    unstructured==0.16.5 \
#    unstructured[pdf]==0.16.5

# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Provide your GROQ API TOKEN")
# Out:
# Provide your GROQ API TOKEN··········

# %%
# Document Loader
from langchain.document_loaders import TextLoader
loader = TextLoader('/content/drive/MyDrive/Colab Notebooks/india.txt')
documents = loader.load()

# %%
documents
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/Colab Notebooks/india.txt'}, page_content='Here are **10-line short, simple content pieces** for each topic you asked:\n(Cricket, Politics, Actors, Environment, Nature)\n\n---\n\n# 🏏 **10 Lines About Cricket**\n\n1. Cricket is one of the most popular sports in the world.\n2. It is played between two teams of eleven players each.\n3. The game includes batting, bowling, and fielding skills.\n4. Test, ODI, and T20 are the three main formats.\n5. T20 cricket is the fastest and most exciting format.\n6. A batsman scores runs by hitting the ball.\n7. Bowlers try to take wickets to stop the runs.\n8. Fielders support the team with catches and run-outs.\n9. Strategy and teamwork play a big role in winning.\n10. Cricket creates passion, excitement, and unity among fans.\n\n---\n\n# 🏛️ **10 Lines About Politics**\n\n1. Politics is the system used to govern a country or region.\n2. Leaders and representatives make decisions for the people.\n3. Political parties reflect different ideologies and ideas.\n4. Elections allow citizens to choose their leaders.\n5. Good governance focuses on development and welfare.\n6. Policies shape education, health, economy, and society.\n7. Democracy gives people the right to vote and express views.\n8. Political debates help understand different perspectives.\n9. Responsible leadership brings stability and progress.\n10. Politics affects every aspect of daily life.\n\n---\n\n# 🎬 **10 Lines About Actors**\n\n1. Actors bring stories to life through their performances.\n2. They work in movies, TV shows, theatre, and digital platforms.\n3. Good acting requires emotion, expression, and timing.\n4. Actors often prepare by learning scripts and practicing scenes.\n5. Some actors become global icons due to their talent.\n6. They use body language and voice to create impact.\n7. Many actors inspire millions with their roles.\n8. Behind the scenes, they work long hours and face challenges.\n9. Awards and recognition encourage their hard work.\n10. Actors help audiences connect to characters and emotions.\n\n---\n\n# 🌍 **10 Lines About Environment**\n\n1. The environment includes air, water, land, and living organisms.\n2. A healthy environment is essential for human survival.\n3. Pollution is harming our natural resources.\n4. Climate change is causing global temperature rise.\n5. Deforestation reduces biodiversity and affects rainfall.\n6. Recycling and waste management protect the environment.\n7. Renewable energy reduces dependency on fossil fuels.\n8. Saving water and electricity conserves natural resources.\n9. Governments and individuals must work together.\n10. Protecting the environment ensures a safe future.\n\n---\n\n# 🍃 **10 Lines About Nature**\n\n1. Nature includes forests, rivers, mountains, and wildlife.\n2. It provides beauty, peace, and inspiration.\n3. Plants and animals maintain the balance of life.\n4. The sound of rain, wind, and birds calms the mind.\n5. Nature gives us fresh air and clean water.\n6. Seasons change the landscapes with unique charm.\n7. Humans depend on nature for food and shelter.\n8. Preserving nature is our responsibility.\n9. Natural places refresh the body and soul.\n10. Nature is the greatest gift to humanity.\n\n---\n\nIf you want, I can convert these into:\n✅ Paragraph format\n✅ Simple English for kids\n✅ Professional English\n✅ Social media captions\n')]

# %%
import textwrap

def wrap_text_preserve_newlines(text, width=110):
    # Split the input text into lines based on newline characters
    lines = text.split('\n')

    # Wrap each line individually
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    # Join the wrapped lines back together using newline characters
    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text

# %%
print(wrap_text_preserve_newlines(str(documents[0])))
# Out:
# page_content='Here are **10-line short, simple content pieces** for each topic you asked:
# (Cricket, Politics, Actors, Environment, Nature)
#
# ---
#
# # 🏏 **10 Lines About Cricket**
#
# 1. Cricket is one of the most popular sports in the world.
# 2. It is played between two teams of eleven players each.
# 3. The game includes batting, bowling, and fielding skills.
# 4. Test, ODI, and T20 are the three main formats.
# 5. T20 cricket is the fastest and most exciting format.
# 6. A batsman scores runs by hitting the ball.
# 7. Bowlers try to take wickets to stop the runs.
# 8. Fielders support the team with catches and run-outs.
# 9. Strategy and teamwork play a big role in winning.
# 10. Cricket creates passion, excitement, and unity among fans.
#
# ---
#
# # 🏛️ **10 Lines About Politics**
#
# 1. Politics is the system used to govern a country or region.
# 2. Leaders and representatives make decisions for the people.
# 3. Political parties reflect different ideologies and ideas.
# 4. Elections allow citizens to choose their leaders.
# 5. Good governance focuses on development and welfare.
# 6. Policies shape education, health, economy, and society.
# 7. Democracy gives people the right to vote and express views.
# 8. Political debates help understand different perspectives.
# 9. Responsible leadership brings stability and progress.
# 10. Politics affects every aspect of daily life.
#
# ---
#
# # 🎬 **10 Lines About Actors**
#
# 1. Actors bring stories to life through their performances.
# 2. They work in movies, TV shows, theatre, and digital platforms.
# 3. Good acting requires emotion, expression, and timing.
# 4. Actors often prepare by learning scripts and practicing scenes.
# 5. Some actors become global icons due to their talent.
# 6. They use body language and voice to create impact.
# 7. Many actors inspire millions with their roles.
# 8. Behind the scenes, they work long hours and face challenges.
# 9. Awards and recognition encourage their hard work.
# 10. Actors help audiences connect to characters and emotions.
#
# ---
#
# # 🌍 **10 Lines About Environment**
#
# 1. The environment includes air, water, land, and living organisms.
# 2. A healthy environment is essential for human survival.
# 3. Pollution is harming our natural resources.
# 4. Climate change is causing global temperature rise.
# 5. Deforestation reduces biodiversity and affects rainfall.
# 6. Recycling and waste management protect the environment.
# 7. Renewable energy reduces dependency on fossil fuels.
# 8. Saving water and electricity conserves natural resources.
# 9. Governments and individuals must work together.
# 10. Protecting the environment ensures a safe future.
#
# ---
#
# # 🍃 **10 Lines About Nature**
#
# 1. Nature includes forests, rivers, mountains, and wildlife.
# 2. It provides beauty, peace, and inspiration.
# 3. Plants and animals maintain the balance of life.
# 4. The sound of rain, wind, and birds calms the mind.
# 5. Nature gives us fresh air and clean water.
# 6. Seasons change the landscapes with unique charm.
# 7. Humans depend on nature for food and shelter.
# 8. Preserving nature is our responsibility.
# 9. Natural places refresh the body and soul.
# 10. Nature is the greatest gift to humanity.
#
# ---
#
# If you want, I can convert these into:
# ✅ Paragraph format
# ✅ Simple English for kids
# ✅ Professional English
# ✅ Social media captions
# ' metadata={'source': '/content/drive/MyDrive/Colab Notebooks/india.txt'}

# %%
# Text Splitter
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# %%
len(docs)
# Out:
# 5

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()
# Out:
# /tmp/ipython-input-1664678352.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   embeddings = HuggingFaceEmbeddings()
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from langchain.vectorstores import FAISS

# Install faiss-cpu as faiss-gpu failed
# !pip install faiss-cpu

db = FAISS.from_documents(docs, embeddings)
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.0-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.13.0-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 89.3 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.0

# %%
query = "explain about cricket"
docs = db.similarity_search(query)

# %%
print(wrap_text_preserve_newlines(str(docs[0].page_content)))
# Out:
# Here are **10-line short, simple content pieces** for each topic you asked:
# (Cricket, Politics, Actors, Environment, Nature)
#
# ---
#
# # 🏏 **10 Lines About Cricket**
#
# 1. Cricket is one of the most popular sports in the world.
# 2. It is played between two teams of eleven players each.
# 3. The game includes batting, bowling, and fielding skills.
# 4. Test, ODI, and T20 are the three main formats.
# 5. T20 cricket is the fastest and most exciting format.
# 6. A batsman scores runs by hitting the ball.
# 7. Bowlers try to take wickets to stop the runs.
# 8. Fielders support the team with catches and run-outs.
# 9. Strategy and teamwork play a big role in winning.
# 10. Cricket creates passion, excitement, and unity among fans.
#
# ---
#
# # 🏛️ **10 Lines About Politics**
