# %%
#pip install -U "langchain[openai]"

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

model = init_chat_model("gpt-5.2")

# %%
response = model.invoke("Who is conducting 2026 t20 cricket world cup?")

# %%
print(response)
# Out:
# content='The **2026 ICC Men’s T20 Cricket World Cup** will be **hosted (conducted) by India and Sri Lanka**, jointly. It’s scheduled for **February–March 2026**.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 46, 'prompt_tokens': 18, 'total_tokens': 64, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.2-2025-12-11', 'system_fingerprint': None, 'id': 'chatcmpl-DGQBbw6N1u1LvsiV3b6yIM5s8PF5P', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019cc37d-0f4d-7273-9840-b3e572867a67-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 18, 'output_tokens': 46, 'total_tokens': 64, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
