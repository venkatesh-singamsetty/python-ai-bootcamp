# %%
#pip install -U "langchain[google-genai]"

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("Who is conducting 2026 t20 cricket world cup?")

# %%
print(response)
# Out:
# content='The 2026 T20 Cricket World Cup will be jointly hosted by **India and Sri Lanka**.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019cc37c-a8bf-7d41-a205-6e69c68bf452-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 23, 'total_tokens': 39, 'input_token_details': {'cache_read': 0}}
