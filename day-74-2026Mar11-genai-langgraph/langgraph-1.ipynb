# %%
pip install "langgraph<1.1.0"
# Out:
# Requirement already satisfied: langgraph<1.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (1.0.10)
# Requirement already satisfied: langchain-core>=0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph<1.1.0) (1.2.13)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph<1.1.0) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph<1.1.0) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph<1.1.0) (0.3.6)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph<1.1.0) (2.12.5)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph<1.1.0) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0) (3.11.7)
# Requirement already satisfied: anyio in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0) (4.12.1)
# Requirement already satisfied: certifi in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0) (1.0.9)
# Requirement already satisfied: idna in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph<1.1.0) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph<1.1.0) (0.7.3)
# Requirement already satisfied: packaging>=23.2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph<1.1.0) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph<1.1.0) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph<1.1.0) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph<1.1.0) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph<1.1.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph<1.1.0) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<1.1.0) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<1.1.0) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<1.1.0) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph<1.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph<1.1.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph<1.1.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<1.1.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph<1.1.0) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from IPython.display import Image, display

# %%
class MyState(TypedDict):
    message: str
# Define the start node
def start_node(state: MyState) -> MyState:
    print("Start node received:", state["message"])
    # Process or pass the message to the end node
    return {"message": state["message"] + " -> processed by start"}
# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state
# Build the graph
builder = StateGraph(MyState)

# %%
# Add nodes
builder.add_node("start", start_node)
builder.add_node("end", end_node)

# %%
# Define the flow
builder.set_entry_point("start")
builder.add_edge("start", "end")
builder.add_edge("end", END)  # END is a special marker for graph completion

# %%
# Compile the graph
graph = builder.compile()
# Run the graph
result = graph.invoke({"message": "Hello LangGraph"})
print("Final result:", result["message"])
# Out:
# Start node received: Hello LangGraph
# End node received: Hello LangGraph -> processed by start
# Final result: Hello LangGraph -> processed by start
