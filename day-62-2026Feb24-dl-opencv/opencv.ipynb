# %%
import cv2

# %%
input = cv2.imread(r'/Users/venkat/Downloads/myimage.jpg')

# %%
input
# Out:
# array([[[  2,   2,   2],
#         [  3,   3,   3],
#         [  2,   2,   2],
#         ...,
#         [  2,   2,   2],
#         [  2,   2,   2],
#         [  2,   2,   2]],
#
#        [[  3,   3,   3],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [  2,   2,   2]],
#
#        [[  2,   2,   2],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [  2,   2,   2]],
#
#        ...,
#
#        [[  3,   3,   3],
#         [151, 121, 116],
#         [188, 170, 171],
#         ...,
#         [160, 124, 116],
#         [151, 119, 114],
#         [  3,   1,   0]],
#
#        [[  4,   2,   2],
#         [164, 136, 135],
#         [211, 198, 200],
#         ...,
#         [154, 119, 109],
#         [140, 109, 106],
#         [  4,   2,   2]],
#
#        [[  1,   3,   3],
#         [170, 149, 147],
#         [229, 223, 224],
#         ...,
#         [149, 114, 104],
#         [135, 104, 101],
#         [  4,   2,   2]]], shape=(709, 551, 3), dtype=uint8)

# %%
wrong_img = cv2.imread(r'/Users/venkat/Downloads/dog.jpg')  # cv2.imread never gives ERROR even the file does not exist
# Out:
# [ WARN:0@127.265] global loadsave.cpp:278 findDecoder imread_('/Users/venkat/Downloads/dog.jpg'): can't open/read file: check file path/integrity

# %%
type(wrong_img)
# Out:
# NoneType

# %%
type(input)
# Out:
# numpy.ndarray

# %%
import cv2

img = cv2.imread('/Users/venkat/Downloads/myimage.jpg')

cv2.imshow('venky', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)   # required on macOS
