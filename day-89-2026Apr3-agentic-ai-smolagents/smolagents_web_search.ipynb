# %%
pip install "smolagents[toolkit]"
# Out:
# Requirement already satisfied: smolagents[toolkit] in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (1.24.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from smolagents[toolkit]) (0.36.2)
# Requirement already satisfied: requests>=2.32.3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from smolagents[toolkit]) (2.32.5)
# Requirement already satisfied: rich>=13.9.4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from smolagents[toolkit]) (14.3.2)
# Requirement already satisfied: jinja2>=3.1.4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from smolagents[toolkit]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from smolagents[toolkit]) (12.1.0)
# Requirement already satisfied: python-dotenv in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from smolagents[toolkit]) (1.0.1)
# Requirement already satisfied: ddgs>=9.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from smolagents[toolkit]) (9.12.1)
# Collecting markdownify>=0.14.1 (from smolagents[toolkit])
#   Downloading markdownify-1.2.2-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: filelock in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[toolkit]) (3.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[toolkit]) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[toolkit]) (1.3.2)
# Requirement already satisfied: packaging>=20.9 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[toolkit]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[toolkit]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[toolkit]) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[toolkit]) (4.15.0)
# Requirement already satisfied: click>=8.1.8 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ddgs>=9.0.0->smolagents[toolkit]) (8.1.8)
# Requirement already satisfied: primp>=1.2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ddgs>=9.0.0->smolagents[toolkit]) (1.2.2)
# Requirement already satisfied: lxml>=4.9.4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from ddgs>=9.0.0->smolagents[toolkit]) (6.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from jinja2>=3.1.4->smolagents[toolkit]) (3.0.3)
# Collecting beautifulsoup4<5,>=4.9 (from markdownify>=0.14.1->smolagents[toolkit])
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: six<2,>=1.15 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from markdownify>=0.14.1->smolagents[toolkit]) (1.17.0)
# Collecting soupsieve>=1.6.1 (from beautifulsoup4<5,>=4.9->markdownify>=0.14.1->smolagents[toolkit])
#   Using cached soupsieve-2.8.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[toolkit]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[toolkit]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[toolkit]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests>=2.32.3->smolagents[toolkit]) (2026.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from rich>=13.9.4->smolagents[toolkit]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from rich>=13.9.4->smolagents[toolkit]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[toolkit]) (0.1.2)
# Downloading markdownify-1.2.2-py3-none-any.whl (15 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.3-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4, markdownify
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [markdownify]
# Successfully installed beautifulsoup4-4.14.3 markdownify-1.2.2 soupsieve-2.8.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel

os.environ["HF_TOKEN"] = "xxxx" 

model = InferenceClientModel()
agent = CodeAgent(tools=[WebSearchTool()], model=model, stream_outputs=True)

agent.run("How many seconds would it take for a leopard at full speed to run through Pont des Arts?")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ How many seconds would it take for a leopard at full speed to run through Pont des Arts?                        │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   bridge_length_search = web_search(query="Pont des Arts length")
#   print(bridge_length_search)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Pont des Arts - Wikipedia](https://en.wikipedia.org/wiki/Pont_des_Arts)
# The Pont  des  Arts (French pronunciation: [pɔ̃ dez‿aʁ]) or Passerelle des  Arts ([pasʁɛl -]) is a pedestrian bridge
# in Paris which crosses the River Seine. It links the Institut de France and the central square (cour carrée) of the
# Palais du Louvre, which had been termed the "Palais des  Arts " under the First French Empire.
#
# [Pont des Arts - All you Need to Know (2026)](https://www.theparisianguide.com/s/pont-des-arts/)
# The Pont  des  Arts , connecting the Louvre and the Institut de France, holds a prominent place not only in
# Parisian architecture but also in the city's heart.
#
# [10 Picturesque Facts About The Pont Des Arts](https://art-facts.com/pont-des-arts-facts/)
# In this article, we'll take a closer look at some of the most interesting facts about the Pont  des  Arts , a
# remarkable structure in the City of Light.
#
# [Pont des Arts, Paris, France - LatLong](https://www.latlong.net/place/pont-des-arts-paris-france-32945.html)
#  Pont  des  Arts is a scenic pedestrian bridge over the Seine River in Paris, France. The bridge connects the Musée
# du Louvre and the Institut de France. It has a length of 155 m (509 ft) and a width of 11 m (36 ft). It was
# constructed between 1981 and 1984. The bridge is part of the UNESCO World Heritage Site. Pont  des  Arts has been
# featured in numerous movies and television series such as ...
#
# [Everything you need to know about the Pont des Arts! Pont des
# Arts](https://www.cometoparis.com/paris-guide/paris-monuments/pont-des-arts-s959)
# The Pont  des  Arts , a true Parisian icon, is one of the most famous pedestrian crossings in the capital. Located
# between the Institut de France and the Louvre Palace, it offers breathtaking views of the Seine and attracts both
# lovers and street artists as well as strollers. In this article, we invite you to discover the fascinating history
# of the Pont  des  Arts , the details of its latest ...
#
# [Pont des Arts Paris Travel Guide | Paris Insiders
# Guide](https://www.parisinsidersguide.com/pont-des-arts-paris.html)
#  Pont  des  Arts Paris - A River Crossing With Style Since 1804 Pont  des  Arts Paris has long punched above its
# weight. A thin ribbon of iron stretched across the Seine, it isn't the biggest or flashiest of the Paris bridges.
# But what it lacks in size, it makes up for with history, charm, and a surprising number of wine-fueled picnics.
# From student gatherings to sketchbook-toting artists, this ...
#
# [10 things to know about the Pont des Arts in Paris.](https://www.pariscadenas.com/en/articles/read/art-bridge)
# The Pont  des  Arts is a wooden pedestrian bridge that connects the two sides of the Seine in Paris, between the
# Louvre and the rue de Seine. It was built between 1802 and 1804 by architect Louis-Alexandre de Cessart and
# engineer Jean-Rodolphe Perronet. The Pont  des  Arts is the first wooden bridge to be built over the Seine in
# Paris.
#
# [The Pont Des Arts Size | KnowSize](https://knowsize.com/the-pont-des-arts-size/article)
# The Pont  des  Arts in Paris is located on the banks of the Seine and was built in 1804. In 1804, Napoleon I
# ordered the construction of the Pont  des  Arts to connect the L'Institut de France and the Palais des  Arts for
# pedestrians. The original Pont  des  Arts are the oldest metal bridge in Paris. The current Pont  des  Arts is a
# replica.
#
# [Pont des Arts - Seine.com](https://seine.com/bridges/pont-des-arts.php)
#  Pont  des  Arts Bridges Across the Seine > Pont  des  Arts Introduction to the bridge Pont  des  Arts The Pont
# des  Arts is one of Paris's most romantic and iconic pedestrian bridges, connecting the Louvre Museum on the Right
# Bank with the Institut de France on the Left Bank.
#
# [Pont des Arts explained](https://everything.explained.today/Pont_des_Arts/)
# The Pont  des  Arts is also frequently a spot for picnic s during the summer. The Argentine writer, Julio Cortázar,
# talks about this bridge in his 1963 book Rayuela. When Horacio Oliveira goes with the pythia and this tells him
# that the bridge for La Maga is the " Ponts  des  Arts ".
#
# Out: None
# [Step 1: Duration 17.31 seconds| Input tokens: 2,097 | Output tokens: 3,439]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   leopard_speed_search = web_search(query="leopard top speed in km/h")
#   print(leopard_speed_search)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [How Fast Can a Leopard Run? It's Slower than Most of Its Prey](https://africafreak.com/how-fast-can-a-leopard-run)
# African leopards have a top  speed of 56 - 60 km/h (35 - 37 mph). But they can hunt animals that are much faster
# than they are. This article explains it all.
#
# [How Fast Are Leopards? Top Speeds and How It Compares Other Big
# Cats](https://a-z-animals.com/blog/how-fast-leopards-top-speeds-how-compares-other-big-cats/)
# When it comes to swiftness, other big cats are within the range of leopards and cheetahs. Tiger s can run between
# 30-40 miles per hour, and lions 50 miles per hour. Snow leopards are not much faster than their "regular" leopard
# relatives, maxing out at around 40 miles per hour.
#
# [How Fast Is A Leopard? | Bite-Sized Knowledge - UntamedAnimals](https://untamedanimals.com/how-fast-is-a-leopard/)
# How fast is a leopard ? Leopards can run fast but they are not the fastest cats in the wild. Their top  speed is 36
# mph or 58 km/h which puts them in the last spot among big cats. They do not rely solely on speed to catch their
# prey, after all, most of their prey is faster than they are. For example, impalas can run up to 55 mph or 90 km/h .
# Leopards hunt mainly during the night and rely on their ...
#
# [How Fast Can a Leopard Run? A Fascinating Look at Their
# Speed](https://tiger-universe.com/blogs/tiger-blog/how-fast-can-a-leopard-run)
# But they can keep up their top  speed a bit longer. Jaguars, living in the same areas, have similar speeds under
# perfect conditions. Yet, slimmer mountain lions or pumas can hit speeds up to 80 km/h , challenging the leopard's
# rank in speed among the big cat family.
#
# [Leopard Speed and How It Compares to the
# Cheetah](https://www.johansiggesson.com/posts/leopard-speed-and-how-it-compares-to-the-cheetah)
# Explore leopard  speed , how it helps in hunting, and how it compares to cheetah speed . A grounded look at leopard
# behavior for wildlife lovers and photographers.
#
# [How Fast Is A Leopard? Top Speed & Acceleration](https://scalecompanions.com/how-fast-is-a-leopard/)
# Learn about the amazing speed of leopards—from top  speed to acceleration rates and their incredible hunting
# prowess. Discover how fast these fierce predators can run and chase prey in this comprehensive guide. Top  Speed
# Recorded Maximum When we talk about top  speed  in vehicles or animals, it's like asking what's the peak
# performance when all systems are maxed out. For cars, this is often ...
#
# [Leopard Speed: How Fast Can a Leopard Run? (MPH & KM/H)](https://onelearning.blog/leopard-speed-run-fast-71841)
# Discover how fast leopards run, their incredible top  speeds  in MPH & KM/H , and what makes them apex predators.
# Learn about their hunting tactics and physical prowess. Read now!
#
# [How fast can leopards run and how agile are they? -
# WildLifeFAQs](https://www.wildlifefaq.com/leopard-speed-and-agility/)
# The Speed and Agility of Amur Leopards Amur leopards , a subspecies of leopard , are known for their exceptional
# speed and agility. These magnificent creatures can reach speeds of almost 37 miles per hour (58 km/h ), allowing
# them to swiftly chase down prey and escape potential threats.
#
# [Leopard's Agile Movement And Impressive Speed - Big Cat
# Facts](https://bigcatfacts.net/leopards-agile-movement-and-impressive-speed/)
# Introduction to the Agile Leopard  In the realm of the animal kingdom, the agile leopard holds a considerable
# place. Recognized as being one of a few top predators, leopards are best known for their astonishing speed ,
# agility, and strength. In stark contrast to the cheetah—another renowned predator—the leopard's muscular build
# enables it to reach speeds of roughly 58 kilometers per hour ...
#
# Out: None
# [Step 2: Duration 9.66 seconds| Input tokens: 5,383 | Output tokens: 4,999]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   bridge_length = 155  # meters (from web search results)
#   leopard_speed_kmh = 58  # km/h (top speed from multiple sources)
#   speed_mps = leopard_speed_kmh * 1000 / 3600  # convert to meters per second
#   time_seconds = bridge_length / speed_mps
#   final_answer(time_seconds)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 9.620689655172415
# [Step 3: Duration 10.49 seconds| Input tokens: 9,697 | Output tokens: 7,252]
# 9.620689655172415
