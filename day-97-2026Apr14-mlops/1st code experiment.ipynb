# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Define the model hyperparameters
params = {
    "solver": "lbfgs",
    "max_iter": 1000,
    #"multi_class": "auto",
    "random_state": 42,
}

# Train the model
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       270
#            1       0.62      0.50      0.56        30
#
#     accuracy                           0.92       300
#    macro avg       0.79      0.73      0.76       300
# weighted avg       0.91      0.92      0.92       300

# %%
report_dict = classification_report(y_test, y_pred, output_dict=True)
report_dict
# Out:
# {'0': {'precision': 0.9456521739130435,
#   'recall': 0.9666666666666667,
#   'f1-score': 0.9560439560439561,
#   'support': 270.0},
#  '1': {'precision': 0.625,
#   'recall': 0.5,
#   'f1-score': 0.5555555555555556,
#   'support': 30.0},
#  'accuracy': 0.92,
#  'macro avg': {'precision': 0.7853260869565217,
#   'recall': 0.7333333333333334,
#   'f1-score': 0.7557997557997558,
#   'support': 300.0},
#  'weighted avg': {'precision': 0.9135869565217392,
#   'recall': 0.92,
#   'f1-score': 0.9159951159951161,
#   'support': 300.0}}

# %%
pip install mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-3.11.1-py3-none-any.whl.metadata (49 kB)
# Collecting mlflow-skinny==3.11.1 (from mlflow)
#   Using cached mlflow_skinny-3.11.1-py3-none-any.whl.metadata (49 kB)
# Collecting mlflow-tracing==3.11.1 (from mlflow)
#   Using cached mlflow_tracing-3.11.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Using cached flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting Flask<4 (from mlflow)
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: aiohttp<4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (3.13.5)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (46.0.5)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<26 (from mlflow)
#   Using cached gunicorn-25.3.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting huey<3,>=2.5.4 (from mlflow)
#   Using cached huey-2.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: matplotlib<4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (3.10.8)
# Requirement already satisfied: numpy<3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<24,>=4.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: scikit-learn<2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (1.8.0)
# Requirement already satisfied: scipy<2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (1.17.0)
# Collecting skops<1 (from mlflow)
#   Using cached skops-0.13.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow) (2.0.48)
# Requirement already satisfied: cachetools<8,>=5.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (8.1.8)
# Collecting cloudpickle<4 (from mlflow-skinny==3.11.1->mlflow)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.11.1->mlflow)
#   Using cached databricks_sdk-0.102.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: fastapi<1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (0.135.3)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (3.1.46)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (8.5.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.11.1->mlflow)
#   Using cached opentelemetry_api-1.41.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.11.1->mlflow)
#   Using cached opentelemetry_proto-1.41.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.11.1->mlflow)
#   Using cached opentelemetry_sdk-1.41.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: packaging<27 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (26.0)
# Requirement already satisfied: protobuf<8,>=3.12.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (4.25.9)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (1.0.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (2.32.5)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.11.1->mlflow)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from mlflow-skinny==3.11.1->mlflow) (0.42.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from aiohttp<4->mlflow) (1.23.0)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=2.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow) (2.48.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.6.3)
# Requirement already satisfied: starlette>=0.46.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==3.11.1->mlflow) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (1.9.0)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from Flask<4->mlflow) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.11.1->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.11.1->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow) (4.9.1)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.8-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.11.1->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.3.2)
# Collecting protobuf<8,>=3.12.0 (from mlflow-skinny==3.11.1->mlflow)
#   Using cached protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.62b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.11.1->mlflow)
#   Using cached opentelemetry_semantic_conventions-0.62b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pandas<3->mlflow) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.11.1->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.11.1->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.11.1->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.11.1->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.11.1->mlflow) (2026.1.4)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.11.1->mlflow) (0.6.2)
# Requirement already satisfied: joblib>=1.3.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Collecting prettytable>=3.9 (from skops<1->mlflow)
#   Using cached prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: h11>=0.8 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==3.11.1->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (3.0)
# Requirement already satisfied: wcwidth in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from prettytable>=3.9->skops<1->mlflow) (0.6.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from starlette>=0.46.0->fastapi<1->mlflow-skinny==3.11.1->mlflow) (4.12.1)
# Using cached mlflow-3.11.1-py3-none-any.whl (10.5 MB)
# Using cached mlflow_skinny-3.11.1-py3-none-any.whl (3.2 MB)
# Using cached mlflow_tracing-3.11.1-py3-none-any.whl (1.6 MB)
# Using cached alembic-1.18.4-py3-none-any.whl (263 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached databricks_sdk-0.102.0-py3-none-any.whl (838 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached flask-3.1.3-py3-none-any.whl (103 kB)
# Using cached flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached graphql_core-3.2.8-py3-none-any.whl (207 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached gunicorn-25.3.0-py3-none-any.whl (208 kB)
# Using cached huey-2.6.0-py3-none-any.whl (76 kB)
# Using cached opentelemetry_api-1.41.0-py3-none-any.whl (69 kB)
# Using cached opentelemetry_proto-1.41.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.41.0-py3-none-any.whl (180 kB)
# Using cached opentelemetry_semantic_conventions-0.62b0-py3-none-any.whl (231 kB)
# Using cached protobuf-6.33.6-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached skops-0.13.0-py3-none-any.whl (131 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached prettytable-3.17.0-py3-none-any.whl (34 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Installing collected packages: huey, sqlparse, protobuf, prettytable, Mako, itsdangerous, gunicorn, graphql-core, cloudpickle, opentelemetry-proto, opentelemetry-api, graphql-relay, Flask, docker, alembic, skops, opentelemetry-semantic-conventions, graphene, Flask-CORS, opentelemetry-sdk, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.9
#     Uninstalling protobuf-4.25.9:
#       Successfully uninstalled protobuf-4.25.9
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [mlflow]23/24 [mlflow]skinny]]dk]onventions]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# tensorflow 2.16.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.33.6 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# Successfully installed Flask-3.1.3 Flask-CORS-6.0.2 Mako-1.3.10 alembic-1.18.4 cloudpickle-3.1.2 databricks-sdk-0.102.0 docker-7.1.0 graphene-3.4.3 graphql-core-3.2.8 graphql-relay-3.2.0 gunicorn-25.3.0 huey-2.6.0 itsdangerous-2.2.0 mlflow-3.11.1 mlflow-skinny-3.11.1 mlflow-tracing-3.11.1 opentelemetry-api-1.41.0 opentelemetry-proto-1.41.0 opentelemetry-sdk-1.41.0 opentelemetry-semantic-conventions-0.62b0 prettytable-3.17.0 protobuf-6.33.6 skops-0.13.0 sqlparse-0.5.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import mlflow

# %%
mlflow.set_experiment("1st Experiment")
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
#mlflow.set_tracking_uri("http://localhost:5000")

with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics({
        'accuracy': report_dict['accuracy'],
        'recall_class_0': report_dict['0']['recall'],
        'recall_class_1': report_dict['1']['recall'],
        'f1_score_macro': report_dict['macro avg']['f1-score']
    })
    mlflow.sklearn.log_model(lr, "Logistic Regression")
# Out:
# 2026/04/14 07:58:49 INFO mlflow.tracking.fluent: Experiment with name '1st Experiment' does not exist. Creating a new experiment.
# 2026/04/14 07:58:50 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/14 07:58:50 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run smiling-jay-334 at: http://127.0.0.1:5000/#/experiments/1/runs/13f9cc9cdb674fbbba342106d614f22b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
log_reg = LogisticRegression(C=1, solver='liblinear')
log_reg.fit(X_train, y_train)
y_pred_log_reg = log_reg.predict(X_test)
print(classification_report(y_test, y_pred_log_reg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       270
#            1       0.60      0.50      0.55        30
#
#     accuracy                           0.92       300
#    macro avg       0.77      0.73      0.75       300
# weighted avg       0.91      0.92      0.91       300

# %%
rf_clf = RandomForestClassifier(n_estimators=30, max_depth=3)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       270
#            1       0.95      0.63      0.76        30
#
#     accuracy                           0.96       300
#    macro avg       0.96      0.81      0.87       300
# weighted avg       0.96      0.96      0.96       300

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train, y_train)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       270
#            1       0.96      0.80      0.87        30
#
#     accuracy                           0.98       300
#    macro avg       0.97      0.90      0.93       300
# weighted avg       0.98      0.98      0.98       300

# %%
pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.14.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.17.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.8.0)
# Collecting sklearn-compat<0.2,>=0.1.5 (from imbalanced-learn->imblearn)
#   Downloading sklearn_compat-0.1.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: joblib<2,>=1.2.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Users/venkat/workspace/.venv/lib/python3.12/site-packages (from imbalanced-learn->imblearn) (3.6.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.14.1-py3-none-any.whl (235 kB)
# Downloading sklearn_compat-0.1.5-py3-none-any.whl (20 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn, imblearn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [imblearn]
# Successfully installed imbalanced-learn-0.14.1 imblearn-0.0 sklearn-compat-0.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=0)
X_train_res, y_train_res = smt.fit_resample(X_train, y_train)

np.unique(y_train_res, return_counts=True)
# Out:
# (array([0, 1]), array([613, 613]))

# %%
xgb_clf = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_clf.fit(X_train_res, y_train_res)
y_pred_xgb = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       270
#            1       0.76      0.83      0.79        30
#
#     accuracy                           0.96       300
#    macro avg       0.87      0.90      0.88       300
# weighted avg       0.96      0.96      0.96       300

# %%
models = [
    (
        "Logistic Regression", 
        LogisticRegression(C=1, solver='liblinear'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "Random Forest", 
        RandomForestClassifier(n_estimators=30, max_depth=3), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier With SMOTE",
        XGBClassifier(use_label_encoder=False, eval_metric='logloss'), 
        (X_train_res, y_train_res),
        (X_test, y_test)
    )
]

# %%
reports = []

for model_name, model, train_set, test_set in models:
    X_train = train_set[0]
    y_train = train_set[1]
    X_test = test_set[0]
    y_test = test_set[1]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    reports.append(report)

# %%
import mlflow
import mlflow.sklearn
import mlflow.xgboost

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5001")

# %%
# Initialize MLflow
mlflow.set_experiment("imbalanced classification")
mlflow.set_tracking_uri("http://127.0.0.1:5001")

for i, element in enumerate(models):
    model_name = element[0]
    model = element[1]
    report = reports[i]
    
    with mlflow.start_run(run_name=model_name):        
        mlflow.log_param("model", model_name)
        mlflow.log_metric('accuracy', report['accuracy'])
        mlflow.log_metric('recall_class_1', report['1']['recall'])
        mlflow.log_metric('recall_class_0', report['0']['recall'])
        mlflow.log_metric('f1_score_macro', report['macro avg']['f1-score'])        
        
        if "XGB" in model_name:
            mlflow.xgboost.log_model(model, "model")
        else:
            mlflow.sklearn.log_model(model, "model")
# Out:
# 2026/04/14 08:12:02 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/14 08:12:02 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/04/14 08:12:06 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/14 08:12:06 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run Logistic Regression at: http://127.0.0.1:5001/#/experiments/2/runs/48fabcd5db8946fa97ff70e0055b2119
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/2
# 2026/04/14 08:12:09 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Random Forest at: http://127.0.0.1:5001/#/experiments/2/runs/0c467a94c5ae4871b0490993e2b42cff
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/2
# 2026/04/14 08:12:12 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run XGBClassifier at: http://127.0.0.1:5001/#/experiments/2/runs/28bb4f6c7fb5456e838505e6d5da7173
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/2
# 🏃 View run XGBClassifier With SMOTE at: http://127.0.0.1:5001/#/experiments/2/runs/5b16a908d7ba46b7a6d0c9914e73e9db
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/2

# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_res, y_train_res = smt.fit_resample(X_train, y_train)
np.unique(y_train_res, return_counts=True)
# Out:
# (array([0, 1]), array([619, 619]))

# %%
models = [
    (
        "Logistic Regression", 
        {"C": 1, "solver": 'lbfgs'},
        LogisticRegression(), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "Random Forest", 
        {"n_estimators": 30, "max_depth": 3},
        RandomForestClassifier(), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier",
        {"use_label_encoder": False, "eval_metric": 'logloss'},
        XGBClassifier(), 
        (X_train, y_train),
        (X_test, y_test)
    ),
    (
        "XGBClassifier With SMOTE",
        {"use_label_encoder": False, "eval_metric": 'logloss'},
        XGBClassifier(), 
        (X_train_res, y_train_res),
        (X_test, y_test)
    )
]

# %%
reports = []

for model_name, params, model, train_set, test_set in models:
    X_train = train_set[0]
    y_train = train_set[1]
    X_test = test_set[0]
    y_test = test_set[1]
    
    model.set_params(**params)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    reports.append(report)

# %%
import mlflow
import mlflow.sklearn
import mlflow.xgboost

# %%
mlflow.set_tracking_uri("http://localhost:5001")

# %%
# Initialize MLflow
mlflow.set_experiment("deployment model")
mlflow.set_tracking_uri("http://localhost:5001")

for i, element in enumerate(models):
    model_name = element[0]
    params = element[1]
    model = element[2]
    report = reports[i]
    
    with mlflow.start_run(run_name=model_name):        
        mlflow.log_params(params)
        mlflow.log_metrics({
            'accuracy': report['accuracy'],
            'recall_class_1': report['1']['recall'],
            'recall_class_0': report['0']['recall'],
            'f1_score_macro': report['macro avg']['f1-score']
        })  
        
        if "XGB" in model_name:
            mlflow.xgboost.log_model(model, "model")
        else:
            mlflow.sklearn.log_model(model, "model")
# Out:
# 2026/04/14 08:23:14 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/14 08:23:14 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/04/14 08:23:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/14 08:23:17 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 🏃 View run Logistic Regression at: http://localhost:5001/#/experiments/3/runs/acb1395709184f64a63096316ee9f0aa
# 🧪 View experiment at: http://localhost:5001/#/experiments/3
# 2026/04/14 08:23:20 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run Random Forest at: http://localhost:5001/#/experiments/3/runs/bdddda8694ae44cab1509883821a18b0
# 🧪 View experiment at: http://localhost:5001/#/experiments/3
# 2026/04/14 08:23:22 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run XGBClassifier at: http://localhost:5001/#/experiments/3/runs/09b4bf7dff164e60842c90e9683a9492
# 🧪 View experiment at: http://localhost:5001/#/experiments/3
# 🏃 View run XGBClassifier With SMOTE at: http://localhost:5001/#/experiments/3/runs/02eaca79cae64039bc638066624e7de4
# 🧪 View experiment at: http://localhost:5001/#/experiments/3

# %%
model_name = 'XGB-Smote'
run_id=input('Please type RunID')
model_uri = f'runs:/{run_id}/model'

with mlflow.start_run(run_id=run_id):
    mlflow.register_model(model_uri=model_uri, name=model_name)
# Out:
# Registered model 'XGB-Smote' already exists. Creating a new version of this model...
# 2026/04/14 08:25:02 WARNING mlflow.tracking._model_registry.fluent: Run with id 09b4bf7dff164e60842c90e9683a9492 has no artifacts at artifact path 'model', registering model based on models:/m-2028fde648af488c836e6a6f7e8c94b9 instead
# 2026/04/14 08:25:02 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: XGB-Smote, version 1
# 🏃 View run XGBClassifier at: http://localhost:5001/#/experiments/3/runs/09b4bf7dff164e60842c90e9683a9492
# 🧪 View experiment at: http://localhost:5001/#/experiments/3
# Created version '1' of model 'XGB-Smote'.

# %%
model_name = 'XGB-Smote'
model_version = 1
model_uri = f"models:/{model_name}/{model_version}"

loaded_model = mlflow.xgboost.load_model(model_uri)
y_pred = loaded_model.predict(X_test)
y_pred[:4]
# Out:
# Downloading artifacts:   0%|          | 0/5 [00:00<?, ?it/s]
# array([0, 0, 0, 0])

# %%
current_model_uri = f"models:/{model_name}@appserver"
production_model_name = "finalproduction"

client = mlflow.MlflowClient()
client.copy_model_version(src_model_uri=current_model_uri, dst_name=production_model_name)
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/tracking/client.py:4750, in MlflowClient.copy_model_version(self, src_model_uri, dst_name)
#    4749 try:
# -> 4750     src_name, src_version = get_model_name_and_version(client, src_model_uri)
#    4751     src_mv = client.get_model_version(src_name, src_version)
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/store/artifact/utils/models.py:150, in get_model_name_and_version(client, models_uri)
#     149 if model_alias is not None:
# --> 150     mv = client.get_model_version_by_alias(model_name, model_alias)
#     151     return model_name, mv.version
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/tracking/_model_registry/client.py:475, in ModelRegistryClient.get_model_version_by_alias(self, name, alias)
#     465 """Get the model version instance by name and alias.
#     466
#     467 Args:
#    (...)    473
#     474 """
# --> 475 return self.store.get_model_version_by_alias(name, alias)
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/rest_store.py:516, in RestStore.get_model_version_by_alias(self, name, alias)
#     515 req_body = message_to_json(GetModelVersionByAlias(name=name, alias=alias))
# --> 516 response_proto = self._call_endpoint(GetModelVersionByAlias, req_body)
#     517 return ModelVersion.from_proto(response_proto.model_version)
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/rest_store.py:68, in RestStore._call_endpoint(self, api, json_body, call_all_endpoints, extra_headers)
#      67 self._validate_workspace_support_if_specified()
# ---> 68 return super()._call_endpoint(
#      69     api,
#      70     json_body,
#      71     call_all_endpoints=call_all_endpoints,
#      72     extra_headers=extra_headers,
#      73 )
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/store/model_registry/base_rest_store.py:42, in BaseRestStore._call_endpoint(self, api, json_body, call_all_endpoints, extra_headers)
#      41 endpoint, method = self._get_endpoint_from_method(api)
# ---> 42 return call_endpoint(
#      43     self.get_host_creds(), endpoint, method, json_body, response_proto, extra_headers
#      44 )
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:650, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds, expected_status)
#     648     response = http_request(**call_kwargs)
# --> 650 response = verify_rest_response(
#     651     response,
#     652     endpoint,
#     653     expected_status=expected_status,
#     654 )
#     655 if response.status_code == 204:
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/utils/rest_utils.py:361, in verify_rest_response(response, endpoint, expected_status)
#     360 if _can_parse_as_json_object(response.text):
# --> 361     raise RestException(json.loads(response.text))
#     362 else:
#
# RestException: INVALID_PARAMETER_VALUE: Registered model alias appserver not found.
#
# The above exception was the direct cause of the following exception:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[41], line 5
#       2 production_model_name = "finalproduction"
#       4 client = mlflow.MlflowClient()
# ----> 5 client.copy_model_version(src_model_uri=current_model_uri, dst_name=production_model_name)
#
# File ~/workspace/.venv/lib/python3.12/site-packages/mlflow/tracking/client.py:4753, in MlflowClient.copy_model_version(self, src_model_uri, dst_name)
#    4751     src_mv = client.get_model_version(src_name, src_version)
#    4752 except MlflowException as e:
# -> 4753     raise MlflowException(
#    4754         f"Failed to fetch model version from source model URI: '{src_model_uri}'. "
#    4755         f"Error: {e}"
#    4756     ) from e
#    4758 if has_prompt_tag(src_mv._tags):
#    4759     # Prompt should not be used as a model version
#    4760     raise MlflowException(
#    4761         f"Model with uri '{src_model_uri}' not found",
#    4762         RESOURCE_DOES_NOT_EXIST,
#    4763     )
#
# MlflowException: Failed to fetch model version from source model URI: 'models:/XGB-Smote@appserver'. Error: INVALID_PARAMETER_VALUE: Registered model alias appserver not found.
